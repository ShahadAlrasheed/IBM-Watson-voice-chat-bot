# %%
# !pip install ibm_watson

# %%
url = 'https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/7466c2e7-033f-4205-aa78-12bf806129b1'
apikey = '2Ktfc_IGMRCp-or8KjV6ZH1t9jaWUTe6EJy8cIUJNGYB'

# %%
from ibm_watson import TextToSpeechV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
# Setup Service
authenticator = IAMAuthenticator(apikey)
tts = TextToSpeechV1(authenticator=authenticator)
tts.set_service_url(url)

# %% [markdown]
# #Open Audio Source and Convert

# %%
 with open('./speech.mp3', 'wb') as audio_file:
    res = tts.synthesize('Hello World!', accept='audio/mp3', voice='en-US_AllisonV3Voice').get_result()
    audio_file.write(res.content)

# %%
with open('churchill.txt', 'r') as f:
    text = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-2401ec854170> in <module>
# ----> 1 with open('churchill.txt', 'r') as f:
#       2     text = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'churchill.txt'

# %%
text = [line.replace('\n','') for line in text]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-06e040ef8010> in <module>
# ----> 1 text = [line.replace('\n','') for line in text]
#
# NameError: name 'text' is not defined

# %%
text = ''.join(str(line) for line in text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bbc7c8c517c4> in <module>
# ----> 1 text = ''.join(str(line) for line in text)
#
# NameError: name 'text' is not defined

# %%
import json
voices= tts.list_voices().get_result()
print(json.dumps(voices, indent=2))
# Out:
# {
#   "voices": [
#     {
#       "gender": "female",
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "name": "en-GB_CharlotteV3Voice",
#       "customizable": true,
#       "description": "Charlotte: British English female voice. Dnn technology.",
#       "language": "en-GB",
#       "url": "https://api.us-south.text-to-speech.watson.cloud.ibm.com/instances/7466c2e7-033f-4205-aa78-12bf806129b1/v1/voices/en-GB_CharlotteV3Voice"
#     },
#     {
#       "gender": "female",
#       "supported_features": {
#         "custom_pronunciation": true,
#         "voice_transformation": false
#       },
#       "name": "en-US_AllisonV2Voice",
#       "customizable": true,
#       "description": "Allison: American English female voice. Dnn technology.",
#       "language": "en-US",
# ...

# %%
with open('./frere.mp3', 'wb') as audio_file:
    res = tts.synthesize(frere, accept='audio/mp3', voice='fr-FR_ReneeV3Voice').get_result()
    audio_file.write(res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-26cc0115014c> in <module>
#       1 with open('./frere.mp3', 'wb') as audio_file:
# ----> 2     res = tts.synthesize(frere, accept='audio/mp3', voice='fr-FR_ReneeV3Voice').get_result()
#       3     audio_file.write(res.content)
#
# NameError: name 'frere' is not defined
